-- %%
-- BRONZE TABLES CREATED (just to store the data of raw files)

CREATE OR REPLACE TABLE main.default.bronze_sales_shipment_data
TBLPROPERTIES ('delta.columnMapping.mode' = 'name')
AS
SELECT *
FROM read_files(
  '/Volumes/main/default/supply_chain_inventory_management_data/Inventory_Stock_Data.csv',
  format => 'csv',
  header => true
);


CREATE OR REPLACE TABLE main.default.bronze_sales_shipment_data
TBLPROPERTIES ('delta.columnMapping.mode' = 'name')
AS
SELECT *
FROM read_files(
  '/Volumes/main/default/supply_chain_inventory_management_data/Sales_Shipment_Data.csv',
  format => 'csv',
  header => true
);

CREATE OR REPLACE TABLE main.default.bronze_retail_store_inventory
TBLPROPERTIES ('delta.columnMapping.mode' = 'name')
AS
SELECT *
FROM read_files(
  '/Volumes/main/default/supply_chain_inventory_management_data/retail_store_inventory.csv',
  format => 'csv',
  header => true
);

CREATE OR REPLACE TABLE main.default.bronze_supply_chain_data
TBLPROPERTIES ('delta.columnMapping.mode' = 'name')
AS
SELECT *
FROM read_files(
  '/Volumes/main/default/supply_chain_inventory_management_data/supply_chain_data.csv',
  format => 'csv',
  header => true
);

CREATE OR REPLACE TABLE main.default.bronze_warehouse_district_store
TBLPROPERTIES ('delta.columnMapping.mode' = 'name')
AS
SELECT *
FROM read_files(
  '/Volumes/main/default/supply_chain_inventory_management_data/warehouse_district_store.csv',
  format => 'csv',
  header => true
);

CREATE OR REPLACE TABLE main.default.bronze_warehouse_national_central_medical_store
TBLPROPERTIES ('delta.columnMapping.mode' = 'name')
AS
SELECT *
FROM read_files(
  '/Volumes/main/default/supply_chain_inventory_management_data/warehouse_national_central_medical_store.csv',
  format => 'csv',
  header => true
);

CREATE OR REPLACE TABLE main.default.bronze_warehouse_regional_warehouse
TBLPROPERTIES ('delta.columnMapping.mode' = 'name')
AS
SELECT *
FROM read_files(
  '/Volumes/main/default/supply_chain_inventory_management_data/warehouse_regional_warehouse.csv',
  format => 'csv',
  header => true
);

SHOW TABLES IN main.default;

ALTER TABLE main.default.bronze_sales_shipment_data
RENAME TO main.default.bronze_inventory_stock_data;
